# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %%
import sqlite3
connection = sqlite3.connect('data.sqlite')
cursor = connection.cursor()

# %%
cursor.execute('''SELECT * FROM offices;''').fetchall()
# Out:
# [('1',
#   'San Francisco',
#   '+1 650 219 4782',
#   '100 Market Street',
#   'Suite 300',
#   'CA',
#   'USA',
#   '94080',
#   'NA'),
#  ('2',
#   'Boston',
#   '+1 215 837 0825',
#   '1550 Court Place',
#   'Suite 102',
#   'MA',
#   'USA',
#   '02107',
#   'NA'),
#  ('3',
#   'NYC',
#   '+1 212 555 3000',
#   '523 East 53rd Street',
#   'apt. 5A',
#   'NY',
#   'USA',
#   '10022',
#   'NA'),
#  ('4',
#   'Paris',
#   '+33 14 723 4404',
#   "43 Rue Jouffroy D'abbans",
#   '',
#   '',
#   'France',
#   '75017',
#   'EMEA'),
#  ('5',
#   'Tokyo',
#   '+81 33 224 5000',
#   '4-1 Kioicho',
#   '',
#   'Chiyoda-Ku',
#   'Japan',
#   '102-8578',
#   'Japan'),
#  ('6',
#   'Sydney',
#   '+61 2 9264 2451',
#   '5-11 Wentworth Avenue',
#   'Floor #2',
#   '',
#   'Australia',
#   'NSW 2010',
#   'APAC'),
#  ('7',
#   'London',
#   '+44 20 7877 2041',
#   '25 Old Broad Street',
#   'Level 7',
#   '',
#   'UK',
#   'EC2N 1HN',
#   'EMEA')]

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here
cursor.execute('''SELECT employees.firstName, employees.lastName, offices.state, offices.city 
FROM employees JOIN offices USING(officeCode)
ORDER BY employees.firstName ASC, employees.lastName ASC;''').fetchall()
# Out:
# [('Andy', 'Fixter', '', 'Sydney'),
#  ('Anthony', 'Bow', 'CA', 'San Francisco'),
#  ('Barry', 'Jones', '', 'London'),
#  ('Diane', 'Murphy', 'CA', 'San Francisco'),
#  ('Foon Yue', 'Tseng', 'NY', 'NYC'),
#  ('George', 'Vanauf', 'NY', 'NYC'),
#  ('Gerard', 'Bondur', '', 'Paris'),
#  ('Gerard', 'Hernandez', '', 'Paris'),
#  ('Jeff', 'Firrelli', 'CA', 'San Francisco'),
#  ('Julie', 'Firrelli', 'MA', 'Boston'),
#  ('Larry', 'Bott', '', 'London'),
#  ('Leslie', 'Jennings', 'CA', 'San Francisco'),
#  ('Leslie', 'Thompson', 'CA', 'San Francisco'),
#  ('Loui', 'Bondur', '', 'Paris'),
#  ('Mami', 'Nishi', 'Chiyoda-Ku', 'Tokyo'),
#  ('Martin', 'Gerard', '', 'Paris'),
#  ('Mary', 'Patterson', 'CA', 'San Francisco'),
#  ('Pamela', 'Castillo', '', 'Paris'),
#  ('Peter', 'Marsh', '', 'Sydney'),
#  ('Steve', 'Patterson', 'MA', 'Boston'),
#  ('Tom', 'King', '', 'Sydney'),
#  ('William', 'Patterson', '', 'Sydney'),
#  ('Yoshimi', 'Kato', 'Chiyoda-Ku', 'Tokyo')]

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
cursor.execute('''SELECT customers.* , orders.orderNumber, orders.orderDate, orders.status 
FROM customers  JOIN orders USING(customerNumber) ;''').fetchall()
# Out:
# [('103',
#   'Atelier graphique',
#   'Schmitt',
#   'Carine ',
#   '40.32.2555',
#   '54, rue Royale',
#   '',
#   'Nantes',
#   '',
#   '44000',
#   'France',
#   '1370',
#   '21000.00',
#   '10123',
#   '2003-05-20',
#   'Shipped'),
#  ('103',
#   'Atelier graphique',
#   'Schmitt',
#   'Carine ',
#   '40.32.2555',
#   '54, rue Royale',
#   '',
#   'Nantes',
#   '',
#   '44000',
#   'France',
#   '1370',
#   '21000.00',
#   '10298',
#   '2004-09-27',
#   'Shipped'),
#  ('103',
#   'Atelier graphique',
#   'Schmitt',
#   'Carine ',
#   '40.32.2555',
#   '54, rue Royale',
#   '',
#   'Nantes',
#   '',
#   '44000',
#   'France',
#   '1370',
#   '21000.00',
#   '10345',
#   '2004-11-25',
#   'Shipped'),
#  ('112',
#   'Signal Gift Stores',
#   'King',
#   'Jean',
#   '7025551838',
#   '8489 Strong St.',
#   '',
#   'Las Vegas',
#   'NV',
#   '83030',
#   'USA',
#   '1166',
#   '71800.00',
#   '10124',
#   '2003-05-21',
#   'Shipped'),
#  ('112',
#   'Signal Gift Stores',
#   'King',
# ...

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
# Your code here
cursor.execute('''SELECT orders.*, orderDetails.*
FROM orders JOIN orderDetails USING(orderNumber);''').fetchall()
# Out:
# [('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   '10100',
#   'S18_1749',
#   '30',
#   '136.00',
#   '3'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   '10100',
#   'S18_2248',
#   '50',
#   '55.09',
#   '2'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   '10100',
#   'S18_4409',
#   '22',
#   '75.46',
#   '4'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   '10100',
#   'S24_3969',
#   '49',
#   '35.29',
#   '1'),
#  ('10101',
#   '2003-01-09',
#   '2003-01-18',
#   '2003-01-11',
#   'Shipped',
#   'Check on availability.',
#   '128',
#   '10101',
#   'S18_2325',
#   '25',
#   '108.06',
#   '4'),
#  ('10101',
#   '2003-01-09',
#   '2003-01-18',
#   '2003-01-11',
#   'Shipped',
#   'Check on availability.',
#   '128',
#   '10101',
#   'S18_2795',
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and allthe product information for each product in the order.

# %%
# Your code here
cursor.execute('''SELECT orders.*, products.*
FROM orders JOIN orderDetails USING(orderNumber) JOIN products USING(productCode);''').fetchall()
# Out:
# [('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   'S18_1749',
#   '1917 Grand Touring Sedan',
#   'Vintage Cars',
#   '1:18',
#   'Welly Diecast Productions',
#   'This 1:18 scale replica of the 1917 Grand Touring car has all the features you would expect from museum quality reproductions: all four doors and bi-fold hood opening, detailed engine and instrument panel, chrome-look trim, and tufted upholstery, all topped off with a factory baked-enamel finish.',
#   '2724',
#   '86.70',
#   '170.00'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   'S18_2248',
#   '1911 Ford Town Car',
#   'Vintage Cars',
#   '1:18',
#   'Motor City Art Classics',
#   'Features opening hood, opening doors, opening trunk, wide white wall tires, front door arm rests, working steering system.',
#   '540',
#   '33.30',
#   '60.54'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
# ...

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
